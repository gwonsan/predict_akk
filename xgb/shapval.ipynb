# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import shap
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# 데이터 로딩
train = pd.read_csv('../data/train/train_gs_2306_m3_20%.csv')
test = pd.read_csv('../data/remove_zero_gs_2306_m3.csv')
# XGBoost DMatrix 객체 생성
dtrain = xgb.DMatrix(train.drop('target', axis=1), label=train[['target']])
dtest = xgb.DMatrix(test.drop('target', axis=1), label=test[['target']])

# %%
print(test.columns)
# Out:
# Index(['band 1', 'band 2', 'band 3', 'band 4', 'band 5', 'band 6', 'band 7',
#        'band 8', 'band 9', 'band 10',
#        ...
#        'nx141', 'nx142', 'nx143', 'nx144', 'nx145', 'nx146', 'nx147', 'nx148',
#        'nx149', 'nx150'],
#       dtype='object', length=301)

# %%
# 하이퍼파라미터 설정
params = {
    'objective': 'binary:logistic',  # 이진 분류용 로지스틱 손실 함수
    'eta': 0.1,
    'max_depth': 6,
    'eval_metric': 'logloss',  # 로그 손실을 평가 지표로 사용
}
w_list = [(dtrain, 'train'), (dtest, 'test')]

# 모델 학습
num_round = 100
bst = xgb.train(params, dtrain, num_round, evals=w_list)
bst.save_model('../model/gs_m3_20%_2306_boo.model')

# 예측
pred_probs = bst.predict(dtest)
pred = [1 if x > 0.8 else 0 for x in pred_probs]


# 정확도 계산
accuracy = accuracy_score(test[['target']], pred)
print(f"Accuracy: {accuracy:.4f}")

# 컨퓨전 매트릭스 계산 및 출력
cm = confusion_matrix(test[['target']], pred)
print("Confusion Matrix:")
print(cm)

explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(dtest,tree_limit=100)

columns1 = ['nx96','nx97','nx98','nx101']
columns2 = ['nx76', 'nx78', 'nx79', 'nx80', 'nx81']
indices = [test.columns.get_loc(col) - 1 for col in columns1]  # DMatrix에는 target 컬럼이 없으므로 -1 필요

# 선택된 컬럼들에 대한 SHAP 값 추출 및 summary plot 그리기
shap_values_selected = shap_values[:, indices]
shap.summary_plot(shap_values_selected, test[columns1], feature_names=columns1, max_display=50, color_bar=False, auto_size_plot=True, show=False)

# 그래프를 이미지로 저장
output_path = f"gs_06_summary_plot_pos.png"
plt.savefig(output_path, bbox_inches="tight")
plt.close()  # 저장 후 그래프 창 닫기
indices = [test.columns.get_loc(col) - 1 for col in columns2]  # DMatrix에는 target 컬럼이 없으므로 -1 필요

# 선택된 컬럼들에 대한 SHAP 값 추출 및 summary plot 그리기
shap_values_selected = shap_values[:, indices]
shap.summary_plot(shap_values_selected, test[columns2], feature_names=columns2, max_display=50, color_bar=False, auto_size_plot=True, show=False)

# 그래프를 이미지로 저장
output_path = f"gs_06_summary_plot_ne.png"
plt.savefig(output_path, bbox_inches="tight")
plt.close()  # 저장 후 그래프 창 닫기
# Out:
# [0]	train-logloss:0.63461	test-logloss:0.63590
# [1]	train-logloss:0.58547	test-logloss:0.58837
# [2]	train-logloss:0.54481	test-logloss:0.54956
# [3]	train-logloss:0.50838	test-logloss:0.51537
# [4]	train-logloss:0.47704	test-logloss:0.48648
# [5]	train-logloss:0.45097	test-logloss:0.46245
# [6]	train-logloss:0.42769	test-logloss:0.44164
# [7]	train-logloss:0.40556	test-logloss:0.42160
# [8]	train-logloss:0.38883	test-logloss:0.40663
# [9]	train-logloss:0.37289	test-logloss:0.39246
# [10]	train-logloss:0.35727	test-logloss:0.37854
# [11]	train-logloss:0.34355	test-logloss:0.36646
# [12]	train-logloss:0.33175	test-logloss:0.35621
# [13]	train-logloss:0.32143	test-logloss:0.34726
# [14]	train-logloss:0.31201	test-logloss:0.33936
# [15]	train-logloss:0.30355	test-logloss:0.33207
# [16]	train-logloss:0.29616	test-logloss:0.32599
# [17]	train-logloss:0.28811	test-logloss:0.31895
# [18]	train-logloss:0.28121	test-logloss:0.31307
# [19]	train-logloss:0.27561	test-logloss:0.30833
# [20]	train-logloss:0.27065	test-logloss:0.30428
# [21]	train-logloss:0.26511	test-logloss:0.29940
# [22]	train-logloss:0.26084	test-logloss:0.29580
# [23]	train-logloss:0.25708	test-logloss:0.29270
# [24]	train-logloss:0.25376	test-logloss:0.29003
# [25]	train-logloss:0.24968	test-logloss:0.28629
# [26]	train-logloss:0.24678	test-logloss:0.28371
# [27]	train-logloss:0.24360	test-logloss:0.28116
# [28]	train-logloss:0.24127	test-logloss:0.27921
# [29]	train-logloss:0.23916	test-logloss:0.27764
# [30]	train-logloss:0.23696	test-logloss:0.27572
# [31]	train-logloss:0.23516	test-logloss:0.27433
# [32]	train-logloss:0.23345	test-logloss:0.27289
# [33]	train-logloss:0.23070	test-logloss:0.27028
# [34]	train-logloss:0.22888	test-logloss:0.26874
# [35]	train-logloss:0.22752	test-logloss:0.26781
# [36]	train-logloss:0.22505	test-logloss:0.26572
# [37]	train-logloss:0.22388	test-logloss:0.26482
# [38]	train-logloss:0.22200	test-logloss:0.26298
# [39]	train-logloss:0.22107	test-logloss:0.26233
# [40]	train-logloss:0.21951	test-logloss:0.26096
# [41]	train-logloss:0.21729	test-logloss:0.25881
# [42]	train-logloss:0.21596	test-logloss:0.25786
# [43]	train-logloss:0.21441	test-logloss:0.25627
# [44]	train-logloss:0.21352	test-logloss:0.25544
# [45]	train-logloss:0.21110	test-logloss:0.25289
# [46]	train-logloss:0.20972	test-logloss:0.25181
# [47]	train-logloss:0.20831	test-logloss:0.25040
# [48]	train-logloss:0.20707	test-logloss:0.24934
# [49]	train-logloss:0.20583	test-logloss:0.24831
# [50]	train-logloss:0.20406	test-logloss:0.24650
# [51]	train-logloss:0.20305	test-logloss:0.24576
# [52]	train-logloss:0.20180	test-logloss:0.24467
# [53]	train-logloss:0.20083	test-logloss:0.24398
# [54]	train-logloss:0.19987	test-logloss:0.24336
# [55]	train-logloss:0.19828	test-logloss:0.24173
# [56]	train-logloss:0.19730	test-logloss:0.24101
# [57]	train-logloss:0.19614	test-logloss:0.24014
# [58]	train-logloss:0.19502	test-logloss:0.23942
# [59]	train-logloss:0.19416	test-logloss:0.23881
# [60]	train-logloss:0.19312	test-logloss:0.23784
# [61]	train-logloss:0.19210	test-logloss:0.23693
# [62]	train-logloss:0.19119	test-logloss:0.23638
# [63]	train-logloss:0.18977	test-logloss:0.23511
# [64]	train-logloss:0.18945	test-logloss:0.23489
# [65]	train-logloss:0.18815	test-logloss:0.23383
# [66]	train-logloss:0.18724	test-logloss:0.23321
# [67]	train-logloss:0.18596	test-logloss:0.23214
# [68]	train-logloss:0.18523	test-logloss:0.23171
# [69]	train-logloss:0.18448	test-logloss:0.23110
# [70]	train-logloss:0.18367	test-logloss:0.23060
# [71]	train-logloss:0.18315	test-logloss:0.23026
# [72]	train-logloss:0.18195	test-logloss:0.22936
# [73]	train-logloss:0.18143	test-logloss:0.22899
# [74]	train-logloss:0.18088	test-logloss:0.22871
# [75]	train-logloss:0.18004	test-logloss:0.22815
# [76]	train-logloss:0.17892	test-logloss:0.22741
# [77]	train-logloss:0.17855	test-logloss:0.22713
# [78]	train-logloss:0.17752	test-logloss:0.22640
# [79]	train-logloss:0.17659	test-logloss:0.22578
# [80]	train-logloss:0.17627	test-logloss:0.22562
# [81]	train-logloss:0.17594	test-logloss:0.22539
# [82]	train-logloss:0.17497	test-logloss:0.22476
# [83]	train-logloss:0.17398	test-logloss:0.22397
# [84]	train-logloss:0.17370	test-logloss:0.22382
# [85]	train-logloss:0.17325	test-logloss:0.22355
# [86]	train-logloss:0.17257	test-logloss:0.22324
# [87]	train-logloss:0.17218	test-logloss:0.22293
# [88]	train-logloss:0.17133	test-logloss:0.22236
# [89]	train-logloss:0.17102	test-logloss:0.22214
# [90]	train-logloss:0.17050	test-logloss:0.22183
# [91]	train-logloss:0.17009	test-logloss:0.22156
# [92]	train-logloss:0.16970	test-logloss:0.22131
# [93]	train-logloss:0.16938	test-logloss:0.22116
# [94]	train-logloss:0.16884	test-logloss:0.22082
# [95]	train-logloss:0.16806	test-logloss:0.22030
# [96]	train-logloss:0.16730	test-logloss:0.21990
# [97]	train-logloss:0.16668	test-logloss:0.21964
# [98]	train-logloss:0.16646	test-logloss:0.21951
# [99]	train-logloss:0.16590	test-logloss:0.21916
# c:\Users\jmt30\anaconda3\envs\gs\Lib\site-packages\xgboost\core.py:160: UserWarning: [16:28:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.9566
# Confusion Matrix:
# [[6397173  264891]
#  [  32821  165078]]
